# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': ['a', 'b', 'c'],
        'age': [5, 3,2]}
student = pd.DataFrame(data)
student
# Out:
#        שם כיתה  age
# 0    אליז    a    5
# 1  בת שבע    b    3
# 2    גליה    c    2

# %%
student.loc[len(student)]={'שם': 'John', 'כיתה': 'd', 'age': 20}
student
# Out:
#        שם כיתה  age
# 0    אליז    a    5
# 1  בת שבע    b    3
# 2    גליה    c    2
# 3    John    d   20
# 4    John    d   20

# %%
student['שם']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# Name: שם, dtype: object

# %%
student[student['כיתה'] == 'a']
# Out:
#      שם כיתה  ממוצע
# 0  אליז    a      5

# %%
student.describe()
# Out:
#           ממוצע
# count  3.000000
# mean   3.333333
# std    1.527525
# min    2.000000
# 25%    2.500000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
student.describe().tail(1)
# Out:
#      ממוצע
# max    5.0

# %%
df = pd.read_csv("Z:\B\היימן שרה\cities.csv")
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.LatD = df.LatD.fillna(0)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df['LatD'].mean()
# Out:
# 38.8203125

# %%
df['LatD'].min()
# Out:
# 26

# %%
df['LatD'].max()
# Out:
# 50

# %%
df.insert(1, 'is_expensive1', df['LatD']/df['LatD'])
df
# Out:
#      LatD  is_expensive1   "LatM"   "LatS"  is_expensive  "NS"   "LonD"  \
# 0      41            1.0        5       59          True   "N"       80
# 1      42            1.0       52       48          True   "N"       97
# 2      46            1.0       35       59          True   "N"      120
# 3      42            1.0       16       12          True   "N"       71
# 4      43            1.0       37       48          True   "N"       89
# ..    ...            ...      ...      ...           ...   ...      ...
# 123    39            1.0       31       12          True   "N"      119
# 124    50            1.0       25       11          True   "N"      104
# 125    40            1.0       10       48          True   "N"      122
# 126    40            1.0       19       48          True   "N"       75
# 127    41            1.0        9       35          True   "N"       81
#
#       "LonM"   "LonS"  "EW"              "City"  "State"
# ...

# %%
df.rename(columns={'is_expensive1': 'Population'}, inplace=True)
df
# Out:
#      LatD  Population   "LatM"   "LatS"  is_expensive  "NS"   "LonD"   "LonM"  \
# 0      41         1.0        5       59          True   "N"       80       39
# 1      42         1.0       52       48          True   "N"       97       23
# 2      46         1.0       35       59          True   "N"      120       30
# 3      42         1.0       16       12          True   "N"       71       48
# 4      43         1.0       37       48          True   "N"       89       46
# ..    ...         ...      ...      ...           ...   ...      ...      ...
# 123    39         1.0       31       12          True   "N"      119       48
# 124    50         1.0       25       11          True   "N"      104       39
# 125    40         1.0       10       48          True   "N"      122       14
# 126    40         1.0       19       48          True   "N"       75       55
# 127    41         1.0        9       35          True   "N"       81       14
#
# ...

# %%
df[df['LatD'] == 40]
# Out:
#      LatD  Population   "LatM"   "LatS"  is_expensive  "NS"   "LonD"   "LonM"  \
# 15     40         1.0        4       11          True   "N"       80       43
# 45     40         1.0       13       47          True   "N"       74       46
# 58     40         1.0       59       24          True   "N"       75       11
# 61     40         1.0       21       36          True   "N"       80       37
# 62     40         1.0       37       11          True   "N"      103       13
# 96     40         1.0       45       35          True   "N"      111       52
# 125    40         1.0       10       48          True   "N"      122       14
# 126    40         1.0       19       48          True   "N"       75       55
#
#       "LonS"  "EW"             "City"  "State"
# 15        12   "W"         "Wheeling"       WV
# 45        11   "W"          "Trenton"       NJ
# 58        24   "W"      "Stroudsburg"       PA
# 61        12   "W"     "Steubenville"       OH
# ...

# %%
df.sort_values(by='LatD',ascending=True)
# Out:
#      LatD  Population   "LatM"   "LatS"  is_expensive  "NS"   "LonD"   "LonM"  \
# 16     26         1.0       43       11          True   "N"       80        3
# 84     27         1.0       20       24          True   "N"       82       31
# 52     27         1.0       57        0          True   "N"       82       26
# 31     28         1.0       48       35          True   "N"       97        0
# 94     29         1.0       25       12          True   "N"       98       30
# ..    ...         ...      ...      ...           ...   ...      ...      ...
# 68     47         1.0       40       11          True   "N"      117       24
# 10     48         1.0        9        0          True   "N"      103       37
# 33     49         1.0       16       12          True   "N"      123        7
# 6      49         1.0       52       48          True   "N"       97        9
# 124    50         1.0       25       11          True   "N"      104       39
#
# ...
